# %%
import pandas as pd

df = pd.read_csv("./backend/data/reviews.csv")
df
# Out:
#                 id   movie_id  ratings  \
# 0        rw1007328  tt0004972      NaN
# 1        rw1375153  tt0004972      3.0
# 2        rw1139003  tt0004972     10.0
# 3        rw3514927  tt0004972      8.0
# 4        rw1352391  tt0004972      NaN
# ...            ...        ...      ...
# 3396663  rw8092509  tt9907782      6.0
# 3396664  rw8819683  tt9907782      5.0
# 3396665  rw8187676  tt9907782      4.0
# 3396666  rw7998256  tt9907782      6.0
# 3396667  rw7891178  tt9907782      7.0
#
#                                                      title    user_review  \
# 0               The Conventional Wisdom is Partially Right   Snow Leopard
# 1                                      sad relic of racism  planktonrules
# 2                                      The Birth of an Art    Cineanalyst
# 3               Great techniques and a horrible message...       AlsExGal
# 4        Is the historical importance of this film grea...       bbhlthph
# ...

# %%
df.columns
# Out:
# Index(['id', 'movie_id', 'ratings', 'title', 'user_review', 'user_id_review',
#        'date_review', 'total_agree', 'is_spoilers', 'description'],
#       dtype='object')

# %%
df[["title", "date_review", "total_agree", "description"]]
# Out:
#                                                      title       date_review  \
# 0               The Conventional Wisdom is Partially Right   26 January 2005
# 1                                      sad relic of racism       23 May 2006
# 2                                      The Birth of an Art      31 July 2005
# 3               Great techniques and a horrible message...      30 July 2016
# 4        Is the historical importance of this film grea...     26 April 2006
# ...                                                    ...               ...
# 3396663             Loses the menace, keeps the enjoyment.     26 April 2022
# 3396664                Filming in Darkness is Cinematic???   23 January 2023
# 3396665                                      Horses ablaze       30 May 2022
# 3396666                        Good but a little overrated     23 March 2022
# 3396667                                     Poorly planned  23 February 2022
#
# ...
